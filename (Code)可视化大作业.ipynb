# %%
import numpy as np
import pandas as pd
from pyecharts.charts import Pie,Bar,Geo,Parallel,Grid
from pyecharts import options as opts
from pyecharts.globals import ThemeType
from pyecharts.components import Table
from pyecharts.charts import Timeline
from pyecharts.charts import Page

# %%
cm=pd.read_excel(r'cm_position.xlsx')
cm
# Out:
#    session      long         lat  position                   time  works  \
# 0      C84  35.63031  139.791469  东京国际展览中心    2013.8.10-2013.8.12  35000
# 1      C85  35.63031  139.791469  东京国际展览中心  2013.12.29-2013.12.31  35000
# 2      C86  35.63031  139.791469  东京国际展览中心    2014.8.15-2014.8.17  35000
# 3      C87  35.63031  139.791469  东京国际展览中心  2014.12.28-2014.12.30  35000
# 4      C88  35.63031  139.791469  东京国际展览中心    2015.8.14-2014.8.16  35000
# 5      C89  35.63031  139.791469  东京国际展览中心  2015.12.29-2014.12.31  35000
# 6      C90  35.63031  139.791469  东京国际展览中心    2016.8.14-2015.8.16  34000
# 7      C91  35.63031  139.791469  东京国际展览中心  2016.12.29-2016.12.31  36000
# 8      C92  35.63031  139.791469  东京国际展览中心    2017.8.11-2017.8.13  32000
# 9      C93  35.63031  139.791469  东京国际展览中心  2017.12.29-2017.12.31  32000
# 10     C94  35.63031  139.791469  东京国际展览中心    2018.8.10-2018.8.12  35000
# 11     C95  35.63031  139.791469  东京国际展览中心  2018.12.29-2018.12.31  36000
# ...

# %%
#创建地图数据
m1=Geo(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
m1.add_schema('日本')
m1.add_coordinate('c84-东京国际展览中心',139.791469, 35.63031)
m1.add('C84', [('c84-东京国际展览中心',2013)], symbol_size=20)
m1.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
m1.set_global_opts(title_opts=opts.TitleOpts(title='C84展会地址'))

m2=Geo(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
m2.add_schema('日本')
m2.add_coordinate('c85-东京国际展览中心',139.791469, 35.63031)
m2.add('C85', [('c85-东京国际展览中心',2013)], symbol_size=20)
m2.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
m2.set_global_opts(title_opts=opts.TitleOpts(title='C85展会地址'))

m3=Geo(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
m3.add_schema('日本')
m3.add_coordinate('c86-东京国际展览中心',139.791469, 35.63031)
m3.add('C86', [('c86-东京国际展览中心',2014)], symbol_size=20)
m3.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
m3.set_global_opts(title_opts=opts.TitleOpts(title='C86展会地址'))

m4=Geo(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
m4.add_schema('日本')
m4.add_coordinate('c87-东京国际展览中心',139.791469, 35.63031)
m4.add('C87', [('c87-东京国际展览中心',2014)], symbol_size=20)
m4.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
m4.set_global_opts(title_opts=opts.TitleOpts(title='C87展会地址'))

m5=Geo(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
m5.add_schema('日本')
m5.add_coordinate('c88-东京国际展览中心',139.791469, 35.63031)
m5.add('C88', [('c88-东京国际展览中心',2015)], symbol_size=20)
m5.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
m5.set_global_opts(title_opts=opts.TitleOpts(title='C88展会地址'))

m6=Geo(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
m6.add_schema('日本')
m6.add_coordinate('c89-东京国际展览中心',139.791469, 35.63031)
m6.add('C89', [('c89-东京国际展览中心',2015)], symbol_size=20)
m6.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
m6.set_global_opts(title_opts=opts.TitleOpts(title='C89展会地址'))

m7=Geo(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
m7.add_schema('日本')
m7.add_coordinate('c90-东京国际展览中心',139.791469, 35.63031)
m7.add('C90', [('c90-东京国际展览中心',2016)], symbol_size=20)
m7.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
m7.set_global_opts(title_opts=opts.TitleOpts(title='C90展会地址'))

m8=Geo(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
m8.add_schema('日本')
m8.add_coordinate('c91-东京国际展览中心',139.791469, 35.63031)
m8.add('C91', [('c91-东京国际展览中心',2016)], symbol_size=20)
m8.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
m8.set_global_opts(title_opts=opts.TitleOpts(title='C91展会地址'))

m9=Geo(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
m9.add_schema('日本')
m9.add_coordinate('c92-东京国际展览中心',139.791469, 35.63031)
m9.add('C92', [('c92-东京国际展览中心',2017)], symbol_size=20)
m9.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
m9.set_global_opts(title_opts=opts.TitleOpts(title='C92展会地址'))

m10=Geo(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
m10.add_schema('日本')
m10.add_coordinate('c93-东京国际展览中心',139.791469, 35.63031)
m10.add('C93', [('c93-东京国际展览中心',2017)], symbol_size=20)
m10.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
m10.set_global_opts(title_opts=opts.TitleOpts(title='C93展会地址'))

m11=Geo(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
m11.add_schema('日本')
m11.add_coordinate('c94-东京国际展览中心',139.791469, 35.63031)
m11.add('C94', [('c94-东京国际展览中心',2017)], symbol_size=20)
m11.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
m11.set_global_opts(title_opts=opts.TitleOpts(title='C94展会地址'))

m12=Geo(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
m12.add_schema('日本')
m12.add_coordinate('c95-东京国际展览中心',139.791469, 35.63031)
m12.add('C95', [('c95-东京国际展览中心',2018)], symbol_size=20)
m12.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
m12.set_global_opts(title_opts=opts.TitleOpts(title='C95展会地址'))

m13=Geo(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
m13.add_schema('日本')
m13.add_coordinate('c96-东京国际展览中心',139.791469, 35.63031)
m13.add('C96', [('c96-东京国际展览中心',2018)], symbol_size=20)
m13.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
m13.set_global_opts(title_opts=opts.TitleOpts(title='C96展会地址'))

m14=Geo(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
m14.add_schema('日本')
m14.add_coordinate('c97-东京国际展览中心',139.791469, 35.63031)
m14.add('C97', [('c97-东京国际展览中心',2019)], symbol_size=20)
m14.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
m14.set_global_opts(title_opts=opts.TitleOpts(title='C97展会地址'))

m15=Geo(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
m15.add_schema('日本')
m15.add_coordinate('C98-线上',0, 0)
m15.add('C98', [('c98-线上',2019)], symbol_size=20)
m15.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
m15.set_global_opts(title_opts=opts.TitleOpts(title='C98展会地址'))

m16=Geo(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
m16.add_schema('日本')
m16.add_coordinate('C98-线上',0, 0)
m16.add('C98', [('c98-线上',2019)], symbol_size=20)
m16.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
m16.set_global_opts(title_opts=opts.TitleOpts(title='C98展会地址'))

m17=Geo(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
m17.add_schema('日本')
m17.add_coordinate('C98-线上',0, 0)
m17.add('C98', [('c98-线上',2019)], symbol_size=20)
m17.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
m17.set_global_opts(title_opts=opts.TitleOpts(title='C98展会地址'))

m18=Geo(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
m18.add_schema('日本')
m18.add_coordinate('c99-东京国际展览中心',139.791469, 35.63031)
m18.add('C99', [('c99-东京国际展览中心',2021)], symbol_size=20)
m18.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
m18.set_global_opts(title_opts=opts.TitleOpts(title='C99展会地址'))

# %%
#创建时间轴
t1=Timeline(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
t1.add(m1,'2013-8')
t1.add(m2,'2013-12')
t1.add(m3,'2014-8')
t1.add(m4,'2014-12')
t1.add(m5,'2015-8')
t1.add(m6,'2015-12')
t1.add(m7,'2016-8')
t1.add(m8,'2016-12')
t1.add(m9,'2017-8')
t1.add(m10,'2017-12')
t1.add(m11,'2018-8')
t1.add(m12,'2018-12')
t1.add(m13,'2019-8')
t1.add(m14,'2019-12')
t1.add(m15,'2020-8')
t1.add(m16,'2020-12')
t1.add(m17,'2021-8')
t1.add(m18,'2021-12')

t1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', '日本':'https://assets.pyecharts.org/assets/maps/Japan', 'purple-passion':'https://assets.pyecharts.org/assets/themes/purple-passion'
#         }
#     });
# </script>
#
#         <div id="aecf0580facc4206be75288062a55f51" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', '日本', 'purple-passion'], function(echarts) {
#                 var chart_aecf0580facc4206be75288062a55f51 = echarts.init(
#                     document.getElementById('aecf0580facc4206be75288062a55f51'), 'purple-passion', {renderer: 'canvas'});
#                 var option_aecf0580facc4206be75288062a55f51 = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "scatter",
#                 "name": "C99",
#                 "coordinateSystem": "geo",
#                 "symbolSize": 20,
#                 "data": [
# ...

# %%
#创建平行坐标系展示每届的参展人数数据
temp=[]

for i in range(0,16):
    temp.append(cm.iloc[i][6])
data=[temp]
data
# Out:
# [[590000,
#   520000,
#   550000,
#   560000,
#   550000,
#   520000,
#   530000,
#   550000,
#   500000,
#   550000,
#   530000,
#   550000,
#   590000,
#   580000,
#   0,
#   0]]

# %%
#创建平行坐标系展示每届的参展人数
visitor=Parallel(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
parallel_axis=[]

for i in range(0,16):
    parallel_axis.append({'dim':i, 'name':'{}'.format(cm.iloc[i][0])})

data=[]
temp=[]

for i in range(0,16):
    temp.append(cm.iloc[i][6])
data=[temp]
df=[[590000,520000,550000,560000,550000,520000,530000,550000,500000,550000,530000,550000,590000,580000,0,0]]
visitor.add_schema(schema=parallel_axis)
visitor.add(series_name="", data=df)
visitor.set_global_opts(title_opts=opts.TitleOpts(title='10届CM参与人数'), toolbox_opts=opts.ToolboxOpts())
visitor.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'purple-passion':'https://assets.pyecharts.org/assets/themes/purple-passion'
#         }
#     });
# </script>
#
#         <div id="f8e565c642ab4792b41ce48bc35b8fac" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'purple-passion'], function(echarts) {
#                 var chart_f8e565c642ab4792b41ce48bc35b8fac = echarts.init(
#                     document.getElementById('f8e565c642ab4792b41ce48bc35b8fac'), 'purple-passion', {renderer: 'canvas'});
#                 var option_f8e565c642ab4792b41ce48bc35b8fac = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
# ...

# %%
#创建平行坐标系展示每届的作品数量数据
temp2=[]

for i in range(0,16):
    temp2.append(cm.iloc[i][5])
data2=[temp2]
data2
# Out:
# [[35000,
#   35000,
#   35000,
#   35000,
#   35000,
#   35000,
#   34000,
#   36000,
#   32000,
#   32000,
#   35000,
#   36000,
#   36000,
#   36000,
#   36000,
#   35000]]

# %%
work=Parallel(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))

df2=[[35000,35000,35000,35000,35000,35000,34000,36000,32000,32000,35000,36000,36000,36000,36000,35000]]
work.add_schema(schema=parallel_axis)
work.add(series_name="", data=df2)
work.set_global_opts(title_opts=opts.TitleOpts(title='10届CM参与社团数量'), toolbox_opts=opts.ToolboxOpts())
work.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'purple-passion':'https://assets.pyecharts.org/assets/themes/purple-passion'
#         }
#     });
# </script>
#
#         <div id="83601f75db174970971bf44cfd5f2e6f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'purple-passion'], function(echarts) {
#                 var chart_83601f75db174970971bf44cfd5f2e6f = echarts.init(
#                     document.getElementById('83601f75db174970971bf44cfd5f2e6f'), 'purple-passion', {renderer: 'canvas'});
#                 var option_83601f75db174970971bf44cfd5f2e6f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
# ...

# %%
#导入社团数据
works=pd.read_excel(r'works.xlsx')
works
# Out:
#          works session   num  audience   male  female
# 0    东方Project     C84  2548          2  1996     552
# 1        黑子的篮球     C84  1344          0  1306      38
# 2        老虎与兔子     C84   852          0   769      83
# 3         偶像大师     C84   788          2   673     115
# 4         黑塔利亚     C84   590          0     3     587
# ..         ...     ...   ...        ...   ...     ...
# 155      刀剑乱舞      C99   328          0   129     199
# 156  LoveLive!     C99   254          1   129     125
# 157       碧蓝航线     C99   144          2    90      24
# 158      少女与战车     C99   110          2    73      47
# 159      冰上的尤里     C99    74          0    28      46
#
# [160 rows x 6 columns]

# %%
#数据处理，列出每届CM的作品数量信息以及作品男女受众占比
c84=works[works.session=='C84'].groupby('works').head().sort_values('num')
c85=works[works.session=='C85'].groupby('works').head().sort_values('num')
c86=works[works.session=='C86'].groupby('works').head().sort_values('num')
c87=works[works.session=='C87'].groupby('works').head().sort_values('num')
c88=works[works.session=='C88'].groupby('works').head().sort_values('num')
c89=works[works.session=='C89'].groupby('works').head().sort_values('num')
c90=works[works.session=='C90'].groupby('works').head().sort_values('num')
c91=works[works.session=='C91'].groupby('works').head().sort_values('num')
c92=works[works.session=='C92'].groupby('works').head().sort_values('num')
c93=works[works.session=='C93'].groupby('works').head().sort_values('num')
c94=works[works.session=='C94'].groupby('works').head().sort_values('num')
c95=works[works.session=='C95'].groupby('works').head().sort_values('num')
c96=works[works.session=='C96'].groupby('works').head().sort_values('num')
c97=works[works.session=='C97'].groupby('works').head().sort_values('num')
c98=works[works.session=='C98'].groupby('works').head().sort_values('num')
c99=works[works.session=='C99'].groupby('works').head().sort_values('num')
c84
# Out:
#        works session   num  audience   male  female
# 9       网球王子     C84   384          0    28     356
# 8       Fate     C84   399          1   200     199
# 7     歌之王子殿下     C84   404          0     4     400
# 6  VOCALOID      C84   558          1   289     269
# 5   战国BASARA     C84   568          0    35     533
# 4       黑塔利亚     C84   590          0     3     587
# 3       偶像大师     C84   788          2   673     115
# 2      老虎与兔子     C84   852          0   769      83
# 1      黑子的篮球     C84  1344          0  1306      38
# 0  东方Project     C84  2548          2  1996     552

# %%
b1=Bar(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
b1.add_xaxis(c84['works'].tolist())
b1.add_yaxis('C84', c84['num'].tolist())
b1.set_global_opts(title_opts=opts.TitleOpts(title='C84作品数量排名'), toolbox_opts=opts.ToolboxOpts())
b1.reversal_axis()

b2=Bar(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
b2.add_xaxis(c85['works'].tolist())
b2.add_yaxis('C85', c85['num'].tolist())
b2.set_global_opts(title_opts=opts.TitleOpts(title='C85作品数量排名'), toolbox_opts=opts.ToolboxOpts())
b2.reversal_axis()

b3=Bar(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
b3.add_xaxis(c86['works'].tolist())
b3.add_yaxis('C86', c86['num'].tolist())
b3.set_global_opts(title_opts=opts.TitleOpts(title='C86作品数量排名'), toolbox_opts=opts.ToolboxOpts())
b3.reversal_axis()

b4=Bar(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
b4.add_xaxis(c87['works'].tolist())
b4.add_yaxis('C87', c87['num'].tolist())
b4.set_global_opts(title_opts=opts.TitleOpts(title='C87作品数量排名'), toolbox_opts=opts.ToolboxOpts())
b4.reversal_axis()

b5=Bar(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
b5.add_xaxis(c88['works'].tolist())
b5.add_yaxis('C88', c88['num'].tolist())
b5.set_global_opts(title_opts=opts.TitleOpts(title='C88作品数量排名'), toolbox_opts=opts.ToolboxOpts())
b5.reversal_axis()

b6=Bar(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
b6.add_xaxis(c89['works'].tolist())
b6.add_yaxis('C89', c89['num'].tolist())
b6.set_global_opts(title_opts=opts.TitleOpts(title='C89作品数量排名'), toolbox_opts=opts.ToolboxOpts())
b6.reversal_axis()

b7=Bar(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
b7.add_xaxis(c90['works'].tolist())
b7.add_yaxis('C90', c90['num'].tolist())
b7.set_global_opts(title_opts=opts.TitleOpts(title='C90作品数量排名'), toolbox_opts=opts.ToolboxOpts())
b7.reversal_axis()

b8=Bar(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
b8.add_xaxis(c91['works'].tolist())
b8.add_yaxis('C91', c91['num'].tolist())
b8.set_global_opts(title_opts=opts.TitleOpts(title='C91作品数量排名'), toolbox_opts=opts.ToolboxOpts())
b8.reversal_axis()

b9=Bar(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
b9.add_xaxis(c92['works'].tolist())
b9.add_yaxis('C92', c92['num'].tolist())
b9.set_global_opts(title_opts=opts.TitleOpts(title='C92作品数量排名'), toolbox_opts=opts.ToolboxOpts())
b9.reversal_axis()

b10=Bar(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
b10.add_xaxis(c93['works'].tolist())
b10.add_yaxis('C93', c93['num'].tolist())
b10.set_global_opts(title_opts=opts.TitleOpts(title='C93作品数量排名'), toolbox_opts=opts.ToolboxOpts())
b10.reversal_axis()

b11=Bar(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
b11.add_xaxis(c94['works'].tolist())
b11.add_yaxis('C94', c94['num'].tolist())
b11.set_global_opts(title_opts=opts.TitleOpts(title='C94作品数量排名'), toolbox_opts=opts.ToolboxOpts())
b11.reversal_axis()

b12=Bar(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
b12.add_xaxis(c95['works'].tolist())
b12.add_yaxis('C95', c95['num'].tolist())
b12.set_global_opts(title_opts=opts.TitleOpts(title='C95作品数量排名'), toolbox_opts=opts.ToolboxOpts())
b12.reversal_axis()

b13=Bar(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
b13.add_xaxis(c96['works'].tolist())
b13.add_yaxis('C96', c96['num'].tolist())
b13.set_global_opts(title_opts=opts.TitleOpts(title='C96作品数量排名'), toolbox_opts=opts.ToolboxOpts())
b13.reversal_axis()

b14=Bar(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
b14.add_xaxis(c97['works'].tolist())
b14.add_yaxis('C97', c97['num'].tolist())
b14.set_global_opts(title_opts=opts.TitleOpts(title='C97作品数量排名'), toolbox_opts=opts.ToolboxOpts())
b14.reversal_axis()

b15=Bar(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
b15.add_xaxis(c98['works'].tolist())
b15.add_yaxis('C98', c98['num'].tolist())
b15.set_global_opts(title_opts=opts.TitleOpts(title='C98作品数量排名'), toolbox_opts=opts.ToolboxOpts())
b15.reversal_axis()

b16=Bar(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
b16.add_xaxis(c99['works'].tolist())
b16.add_yaxis('C99', c99['num'].tolist())
b16.set_global_opts(title_opts=opts.TitleOpts(title='C99作品数量排名'), toolbox_opts=opts.ToolboxOpts())
b16.reversal_axis()

# %%
#创建时间轴
t2=Timeline(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
t2.add(b1,'2013-8')
t2.add(b2,'2013-12')
t2.add(b3,'2014-8')
t2.add(b4,'2014-12')
t2.add(b5,'2015-8')
t2.add(b6,'2015-12')
t2.add(b7,'2016-8')
t2.add(b8,'2016-12')
t2.add(b9,'2017-8')
t2.add(b10,'2017-12')
t2.add(b11,'2018-8')
t2.add(b12,'2018-12')
t2.add(b13,'2019-8')
t2.add(b14,'2019-12')
t2.add(b15,'2020')
t2.add(b16,'2021-12')

t2.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'purple-passion':'https://assets.pyecharts.org/assets/themes/purple-passion'
#         }
#     });
# </script>
#
#         <div id="f49a9a66db684e1299b6fe545a73beef" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'purple-passion'], function(echarts) {
#                 var chart_f49a9a66db684e1299b6fe545a73beef = echarts.init(
#                     document.getElementById('f49a9a66db684e1299b6fe545a73beef'), 'purple-passion', {renderer: 'canvas'});
#                 var option_f49a9a66db684e1299b6fe545a73beef = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "bar",
#                 "name": "C99",
#                 "legendHoverLink": true,
#                 "data": [
#                     74,
#                     110,
#                     144,
#                     254,
# ...

# %%
c84['male'][0]
c84['female'][0]
# Out:
# 552

# %%
#创建饼图展示作品男女受众
p84=Pie(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
p84\
.add('东方Project',[['Male', 1966],['Female',552]],center=["10%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('黑子的篮球',[['Male', 1306],['Female',38]],center=["30%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('老虎与兔子',[['Male', 769],['Female',83]],center=["50%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('偶像大师',[['Male', 673],['Female',115]],center=["70%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('黑塔利亚',[['Male', 3],['Female',587]],center=["90%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('战国BASARA',[['Male', 35],['Female',533]],center=["10%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('VOCALOID',[['Male', 289],['Female',269]],center=["30%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('歌之王子殿下',[['Male', 4],['Female',400]],center=["50%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('Fate',[['Male', 200],['Female',199]],center=["70%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('网球王子',[['Male', 28],['Female',356]],center=["90%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))

p85=Pie(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
p85\
.add('东方Project',[['Male', 1860],['Female',412]],center=["10%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('黑子的篮球',[['Male', 230],['Female',1232]],center=["30%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('舰队Collection',[['Male', 1086],['Female',50]],center=["50%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('偶像大师',[['Male', 726],['Female',418]],center=["70%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('进击的巨人',[['Male', 280],['Female',418]],center=["90%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('老虎与兔子',[['Male', 130],['Female',558]],center=["10%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('黑塔利亚',[['Male', 53],['Female',408]],center=["30%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('VOCALOID',[['Male', 310],['Female',292]],center=["50%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('战国BASARA',[['Male', 233],['Female',415]],center=["70%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('歌之王子殿下',[['Male', 217],['Female',721]],center=["90%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))

p86=Pie(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
p86\
.add('舰队Collection',[['Male', 1973],['Female',65]],center=["10%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('东方Project',[['Male', 1726],['Female',192]],center=["30%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('黑子的篮球',[['Male', 153],['Female',1291]],center=["50%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('进击的巨人',[['Male', 420],['Female',462]],center=["70%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('偶像大师',[['Male', 783],['Female',47]],center=["90%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('老虎与兔子',[['Male', 210],['Female',370]],center=["10%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('Free!',[['Male', 118],['Female',370]],center=["30%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('LoveLive!',[['Male', 373],['Female',97]],center=["50%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('黑塔利亚',[['Male', 123],['Female',343]],center=["70%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('排球少年',[['Male', 117],['Female',317]],center=["90%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))

p87=Pie(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
p87\
.add('舰队Collection',[['Male', 1997],['Female',555]],center=["10%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('东方Project',[['Male', 1240],['Female',516]],center=["30%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('黑子的篮球',[['Male', 483],['Female',695]],center=["50%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('偶像大师',[['Male', 653],['Female',133]],center=["70%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('排球少年',[['Male', 783],['Female',47]],center=["90%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('飚速宅男',[['Male', 273],['Female',455]],center=["10%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('LoveLive!',[['Male', 576],['Female',92]],center=["30%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('进击的巨人',[['Male', 216],['Female',446]],center=["50%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('老虎与兔子',[['Male', 170],['Female',484]],center=["70%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('Free!',[['Male', 163],['Female',341]],center=["90%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))

p88=Pie(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
p88\
.add('舰队Collection',[['Male', 1860],['Female',706]],center=["10%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('东方Project',[['Male', 1007],['Female',501]],center=["30%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('偶像大师',[['Male', 946],['Female',240]],center=["50%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('排球少年',[['Male', 247],['Female',691]],center=["70%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('黑子的篮球',[['Male', 267],['Female',667]],center=["90%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('飚速宅男',[['Male', 403],['Female',457]],center=["10%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('刀剑乱舞',[['Male', 301],['Female',347]],center=["30%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('LoveLive!',[['Male', 509],['Female',92]],center=["50%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('进击的巨人!',[['Male', 238],['Female',334]],center=["70%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('老虎与兔子',[['Male', 234],['Female',338]],center=["90%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))

p89=Pie(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
p89\
.add('舰队Collection',[['Male', 1860],['Female',706]],center=["10%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('刀剑乱舞',[['Male', 1007],['Female',501]],center=["30%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('东方Project',[['Male', 946],['Female',240]],center=["50%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('偶像大师',[['Male', 247],['Female',691]],center=["70%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('排球少年',[['Male', 267],['Female',667]],center=["90%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('黑子的篮球',[['Male', 403],['Female',457]],center=["10%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('飚速宅男',[['Male', 301],['Female',347]],center=["30%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('LoveLive!',[['Male', 509],['Female',92]],center=["50%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('老虎与兔子',[['Male', 238],['Female',334]],center=["70%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('进击的巨人',[['Male', 234],['Female',338]],center=["90%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))

p90=Pie(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
p90\
.add('舰队Collection',[['Male', 2143],['Female',535]],center=["10%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('东方Project',[['Male', 1038],['Female',587]],center=["30%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('刀剑乱舞',[['Male', 479],['Female',1003]],center=["50%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('偶像大师',[['Male', 1037],['Female',291]],center=["70%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('LoveLive!',[['Male', 468],['Female',135]],center=["90%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('排球少年',[['Male', 240],['Female',332]],center=["10%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('黑子的篮球',[['Male', 206],['Female',302]],center=["30%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('阿松',[['Male', 230],['Female',269]],center=["50%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('飚速宅男',[['Male', 200],['Female',287]],center=["70%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('碧蓝幻想',[['Male', 320],['Female',117]],center=["90%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))

p91=Pie(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
p91\
.add('舰队Collection',[['Male', 2376],['Female',448]],center=["10%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('东方Project',[['Male', 1069],['Female',544]],center=["30%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('刀剑乱舞',[['Male', 683],['Female',818]],center=["50%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('偶像大师',[['Male', 1023],['Female',456]],center=["70%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('LoveLive!',[['Male', 620],['Female',142]],center=["90%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('Fate',[['Male', 311],['Female',311]],center=["10%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('碧蓝幻想',[['Male', 423],['Female',161]],center=["30%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('排球少年',[['Male', 105],['Female',403]],center=["50%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('阿松',[['Male', 120],['Female',373]],center=["70%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('黑子的篮球',[['Male', 123],['Female',288]],center=["90%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))

p92=Pie(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
p92\
.add('舰队Collection',[['Male', 2046],['Female',283]],center=["10%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('东方Project',[['Male', 1106],['Female',214]],center=["30%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('偶像大师',[['Male', 1030],['Female',269]],center=["50%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('刀剑乱舞',[['Male', 530],['Female',714]],center=["70%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('Fate',[['Male', 567],['Female',561]],center=["90%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('Lovelive!',[['Male', 493],['Female',83]],center=["10%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('冰上的尤里',[['Male', 236],['Female',286]],center=["30%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('少女与战车',[['Male', 341],['Female',79]],center=["50%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('碧蓝航线',[['Male', 290],['Female',90]],center=["70%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('排球少年',[['Male', 123],['Female',241]],center=["90%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))

p93=Pie(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
p93\
.add('Fate',[['Male', 1020],['Female',1009]],center=["10%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('舰队Collection',[['Male', 1456],['Female',400]],center=["30%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('偶像大师',[['Male', 1237],['Female',407]],center=["50%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('东方Project',[['Male', 956],['Female',259]],center=["70%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('刀剑乱舞',[['Male', 498],['Female',533]],center=["90%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('Lovelive!',[['Male', 369],['Female',182]],center=["10%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('冰上的尤里',[['Male', 129],['Female',407]],center=["30%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('少女与战车',[['Male', 398],['Female',41]],center=["50%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('VOCALOID',[['Male', 229],['Female',211]],center=["70%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('排球少年',[['Male', 103],['Female',221]],center=["90%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))

p94=Pie(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
p94\
.add('Fate',[['Male', 1129],['Female',1127]],center=["10%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('舰队Collection',[['Male', 1456],['Female',266]],center=["30%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('偶像大师',[['Male', 1064],['Female',421]],center=["50%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('东方Project',[['Male', 986],['Female',369]],center=["70%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('刀剑乱舞',[['Male', 439],['Female',628]],center=["90%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('Lovelive!',[['Male', 276],['Female',269]],center=["10%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('碧蓝航线',[['Male', 540],['Female',46]],center=["30%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('少女与战车',[['Male', 493],['Female',36]],center=["50%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('冰上的尤里',[['Male', 163],['Female',342]],center=["70%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('VOCALOID',[['Male', 195],['Female',186]],center=["90%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))

p95=Pie(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
p95\
.add('Fate',[['Male', 1236],['Female',1270]],center=["10%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('偶像大师',[['Male', 1033],['Female',580]],center=["30%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('舰队Collection',[['Male', 1239],['Female',358]],center=["50%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('东方Project',[['Male', 893],['Female',202]],center=["70%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('刀剑乱舞',[['Male', 239],['Female',620]],center=["90%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('Lovelive!',[['Male', 260],['Female',240]],center=["10%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('Vtuber',[['Male', 380],['Female',65]],center=["30%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('名侦探柯南',[['Male', 156],['Female',223]],center=["50%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('VOCALOID',[['Male', 185],['Female',186]],center=["70%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('冰上的尤里',[['Male', 123],['Female',212]],center=["90%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))

p96=Pie(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
p96\
.add('Fate',[['Male', 1258],['Female',1248]],center=["10%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('舰队Collection',[['Male', 1239],['Female',374]],center=["30%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('偶像大师',[['Male', 1243],['Female',354]],center=["50%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('东方Project',[['Male', 943],['Female',152]],center=["70%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('刀剑乱舞',[['Male', 400],['Female',459]],center=["90%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('Vtuber',[['Male', 400],['Female',100]],center=["10%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('Lovelive!',[['Male', 230],['Female',215]],center=["30%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('名侦探柯南',[['Male', 149],['Female',230]],center=["50%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('碧蓝航线',[['Male', 340],['Female',31]],center=["70%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('少女与战车',[['Male', 290],['Female',45]],center=["90%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))

p97=Pie(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
p97\
.add('Fate',[['Male', 1258],['Female',1259]],center=["10%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('偶像大师',[['Male', 1040],['Female',534]],center=["30%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('舰队Collection',[['Male', 1056],['Female',266]],center=["50%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('东方Project',[['Male', 756],['Female',340]],center=["70%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('Vtuber',[['Male', 653],['Female',183]],center=["90%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('刀剑乱舞',[['Male', 269],['Female',457]],center=["10%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('Lovelive!',[['Male', 223],['Female',216]],center=["30%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('名侦探柯南',[['Male', 200],['Female',214]],center=["50%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('VOCALOID',[['Male', 193],['Female',191]],center=["70%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('碧蓝航线',[['Male', 213],['Female',105]],center=["90%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))

p98=Pie(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
p98\
.add('Fate',[['Male', 780],['Female',760]],center=["10%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('偶像大师',[['Male', 963],['Female',509]],center=["30%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('舰队Collection',[['Male', 1003],['Female',211]],center=["50%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('东方Project',[['Male', 783],['Female',343]],center=["70%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('Vtuber',[['Male', 590],['Female',350]],center=["90%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('刀剑乱舞',[['Male', 360],['Female',442]],center=["10%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('Lovelive!',[['Male', 189],['Female',171]],center=["30%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('碧蓝航线',[['Male', 250],['Female',42]],center=["50%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('少女与战车',[['Male', 113],['Female',77]],center=["70%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('冰上的尤里',[['Male', 73],['Female',129]],center=["90%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))

p99=Pie(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
p99\
.add('偶像大师',[['Male', 493],['Female',389]],center=["10%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('Vtuber',[['Male', 590],['Female',246]],center=["30%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('Fate',[['Male', 395],['Female',387]],center=["50%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('东方Project',[['Male', 453],['Female',317]],center=["70%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('舰队Collection',[['Male', 601],['Female',151]],center=["90%", "30%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('刀剑乱舞',[['Male', 129],['Female',199]],center=["10%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('Lovelive!',[['Male', 129],['Female',125]],center=["30%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('碧蓝航线',[['Male', 90],['Female',24]],center=["50%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('少女与战车',[['Male', 73],['Female',47]],center=["70%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))\
.add('冰上的尤里',[['Male', 28],['Female',46]],center=["90%", "70%"],radius=[30, 40]).set_series_opts(lable_opts=opts.LabelOpts(is_show=True))

# %%
#创建时间轴
t3=Timeline(init_opts=opts.InitOpts(theme=ThemeType.PURPLE_PASSION))
t3.add(p84,'2013-8')
t3.add(p85,'2013-12')
t3.add(p86,'2014-8')
t3.add(p87,'2014-12')
t3.add(p88,'2015-8')
t3.add(p89,'2015-12')
t3.add(p90,'2016-8')
t3.add(p91,'2016-12')
t3.add(p92,'2017-8')
t3.add(p93,'2017-12')
t3.add(p94,'2018-8')
t3.add(p95,'2018-12')
t3.add(p96,'2019-8')
t3.add(p97,'2019-12')
t3.add(p98,'2020')
t3.add(p99,'2021-12')


t3.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'purple-passion':'https://assets.pyecharts.org/assets/themes/purple-passion'
#         }
#     });
# </script>
#
#         <div id="90d796260c214010a1b5461b7a8c53cd" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'purple-passion'], function(echarts) {
#                 var chart_90d796260c214010a1b5461b7a8c53cd = echarts.init(
#                     document.getElementById('90d796260c214010a1b5461b7a8c53cd'), 'purple-passion', {renderer: 'canvas'});
#                 var option_90d796260c214010a1b5461b7a8c53cd = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "pie",
#                 "name": "\u5076\u50cf\u5927\u5e08",
#                 "clockwise": true,
#                 "data": [
#                     {
#                         "name": "Male",
# ...

# %%
#组合地图，柱状图，平行坐标，饼图
page1 = Page(layout=Page.DraggablePageLayout)
page1.add(t1,t2,t3,visitor,work)
page1.render('cm.html')
# Out:
# 'D:\\StudySW\\python\\jupyterProject\\cm.html'

# %%
page1.save_resize_html('cm.html',cfg_file='cm.json', dest='コミックマーケット(大作业).html')
# Out:
# '<!DOCTYPE html>\n<html>\n<head>\n    <meta charset="UTF-8">\n    <title>Awesome-pyecharts</title>\n            <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>\n        <script type="text/javascript" src="https://assets.pyecharts.org/assets/maps/Japan.js"></script>\n        <script type="text/javascript" src="https://assets.pyecharts.org/assets/themes/purple-passion.js"></script>\n        <script type="text/javascript" src="https://assets.pyecharts.org/assets/jquery.min.js"></script>\n        <script type="text/javascript" src="https://assets.pyecharts.org/assets/jquery-ui.min.js"></script>\n        <script type="text/javascript" src="https://assets.pyecharts.org/assets/ResizeSensor.js"></script>\n\n            <link rel="stylesheet"  href="https://assets.pyecharts.org/assets/jquery-ui.css">\n\n</head>\n<body>\n    <style>.box {  }; </style>\n        \n    <div class="box">\n                <div id="6f9935cb4b514533945aa047c5a70e7b" c
# ...
